# %% [markdown]
# # Importation des libreries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from pycaret.classification import *

# %% [markdown]
# # Lecture du dataset

# %%
dataset = pd.read_csv("C46-Diabetes.csv")
dataset.head(6)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0

# %%
# dataset = dataset.drop(["SkinThickness"],axis=1)
dataset = dataset.drop(["Insulin","SkinThickness"],axis=1)
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure   BMI  DiabetesPedigreeFunction  Age  \
# 0            6      148             72  33.6                     0.627   50
# 1            1       85             66  26.6                     0.351   31
# 2            8      183             64  23.3                     0.672   32
# 3            1       89             66  28.1                     0.167   21
# 4            0      137             40  43.1                     2.288   33
#
#    Outcome
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1

# %% [markdown]
# #  Verification de L'integrité du dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   BMI                       768 non-null    float64
#  4   DiabetesPedigreeFunction  768 non-null    float64
#  5   Age                       768 non-null    int64
#  6   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(5)
# memory usage: 42.1 KB

# %% [markdown]
# # Preparation des donnée

# %%
exp_clf = setup(dataset, target="Outcome",train_size=0.8,normalize=True,normalize_method="minmax")
# Out:
# <style type="text/css">
# #T_590e9_row8_col1, #T_590e9_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_590e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_590e9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_590e9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_590e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_590e9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_590e9_row0_col1" class="data row0 col1" >2654</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_590e9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_590e9_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_590e9_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_590e9_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_590e9_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_590e9_row3_col1" class="data row3 col1" >(768, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_590e9_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_590e9_row4_col1" class="data row4 col1" >(768, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_590e9_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_590e9_row5_col1" class="data row5 col1" >(614, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_590e9_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_590e9_row6_col1" class="data row6 col1" >(154, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_590e9_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_590e9_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_590e9_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_590e9_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_590e9_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_590e9_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_590e9_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_590e9_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_590e9_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_590e9_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_590e9_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_590e9_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_590e9_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_590e9_row13_col1" class="data row13 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_590e9_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_590e9_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_590e9_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_590e9_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_590e9_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_590e9_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_590e9_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_590e9_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_590e9_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_590e9_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_590e9_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_590e9_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_590e9_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_590e9_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_590e9_row20_col1" class="data row20 col1" >cf37</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #  Comparaison des modeles

# %%
compare_models(sort = "Accuracy")
# Out:
# <style type="text/css">
# #T_cedba th {
#   text-align: left;
# }
# #T_cedba_row0_col0, #T_cedba_row0_col2, #T_cedba_row0_col4, #T_cedba_row1_col0, #T_cedba_row1_col1, #T_cedba_row1_col2, #T_cedba_row1_col3, #T_cedba_row1_col5, #T_cedba_row1_col6, #T_cedba_row1_col7, #T_cedba_row2_col0, #T_cedba_row2_col1, #T_cedba_row2_col2, #T_cedba_row2_col3, #T_cedba_row2_col4, #T_cedba_row2_col5, #T_cedba_row2_col6, #T_cedba_row2_col7, #T_cedba_row3_col0, #T_cedba_row3_col1, #T_cedba_row3_col2, #T_cedba_row3_col3, #T_cedba_row3_col4, #T_cedba_row3_col5, #T_cedba_row3_col6, #T_cedba_row3_col7, #T_cedba_row4_col0, #T_cedba_row4_col1, #T_cedba_row4_col3, #T_cedba_row4_col4, #T_cedba_row4_col5, #T_cedba_row4_col6, #T_cedba_row4_col7, #T_cedba_row5_col0, #T_cedba_row5_col1, #T_cedba_row5_col2, #T_cedba_row5_col3, #T_cedba_row5_col4, #T_cedba_row5_col5, #T_cedba_row5_col6, #T_cedba_row5_col7, #T_cedba_row6_col0, #T_cedba_row6_col1, #T_cedba_row6_col2, #T_cedba_row6_col3, #T_cedba_row6_col4, #T_cedba_row6_col5, #T_cedba_row6_col6, #T_cedba_row6_col7, #T_cedba_row7_col0, #T_cedba_row7_col1, #T_cedba_row7_col2, #T_cedba_row7_col3, #T_cedba_row7_col4, #T_cedba_row7_col5, #T_cedba_row7_col6, #T_cedba_row7_col7, #T_cedba_row8_col0, #T_cedba_row8_col1, #T_cedba_row8_col2, #T_cedba_row8_col3, #T_cedba_row8_col4, #T_cedba_row8_col5, #T_cedba_row8_col6, #T_cedba_row8_col7, #T_cedba_row9_col0, #T_cedba_row9_col1, #T_cedba_row9_col2, #T_cedba_row9_col3, #T_cedba_row9_col4, #T_cedba_row9_col5, #T_cedba_row9_col6, #T_cedba_row9_col7, #T_cedba_row10_col0, #T_cedba_row10_col1, #T_cedba_row10_col2, #T_cedba_row10_col3, #T_cedba_row10_col4, #T_cedba_row10_col5, #T_cedba_row10_col6, #T_cedba_row10_col7, #T_cedba_row11_col0, #T_cedba_row11_col1, #T_cedba_row11_col2, #T_cedba_row11_col3, #T_cedba_row11_col4, #T_cedba_row11_col5, #T_cedba_row11_col6, #T_cedba_row11_col7, #T_cedba_row12_col0, #T_cedba_row12_col1, #T_cedba_row12_col2, #T_cedba_row12_col3, #T_cedba_row12_col4, #T_cedba_row12_col5, #T_cedba_row12_col6, #T_cedba_row12_col7, #T_cedba_row13_col0, #T_cedba_row13_col1, #T_cedba_row13_col2, #T_cedba_row13_col3, #T_cedba_row13_col4, #T_cedba_row13_col5, #T_cedba_row13_col6, #T_cedba_row13_col7 {
#   text-align: left;
# }
# #T_cedba_row0_col1, #T_cedba_row0_col3, #T_cedba_row0_col5, #T_cedba_row0_col6, #T_cedba_row0_col7, #T_cedba_row1_col4, #T_cedba_row4_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_cedba_row0_col8, #T_cedba_row1_col8, #T_cedba_row2_col8, #T_cedba_row3_col8, #T_cedba_row4_col8, #T_cedba_row5_col8, #T_cedba_row6_col8, #T_cedba_row7_col8, #T_cedba_row8_col8, #T_cedba_row9_col8, #T_cedba_row10_col8, #T_cedba_row11_col8, #T_cedba_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_cedba_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_cedba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cedba_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cedba_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_cedba_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_cedba_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_cedba_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_cedba_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_cedba_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_cedba_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_cedba_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cedba_level0_row0" class="row_heading level0 row0" >svm</th>
#       <td id="T_cedba_row0_col0" class="data row0 col0" >SVM - Linear Kernel</td>
#       <td id="T_cedba_row0_col1" class="data row0 col1" >0.7670</td>
#       <td id="T_cedba_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_cedba_row0_col3" class="data row0 col3" >0.6387</td>
#       <td id="T_cedba_row0_col4" class="data row0 col4" >0.7207</td>
#       <td id="T_cedba_row0_col5" class="data row0 col5" >0.6554</td>
#       <td id="T_cedba_row0_col6" class="data row0 col6" >0.4844</td>
#       <td id="T_cedba_row0_col7" class="data row0 col7" >0.5006</td>
#       <td id="T_cedba_row0_col8" class="data row0 col8" >0.5650</td>
#     </tr>
#     <tr>
#       <th id="T_cedba_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_cedba_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_cedba_row1_col1" class="data row1 col1" >0.7623</td>
#       <td id="T_cedba_row1_col2" class="data row1 col2" >0.8259</td>
#       <td id="T_cedba_row1_col3" class="data row1 col3" >0.5052</td>
#       <td id="T_cedba_row1_col4" class="data row1 col4" >0.7315</td>
#       <td id="T_cedba_row1_col5" class="data row1 col5" >0.5932</td>
#       <td id="T_cedba_row1_col6" class="data row1 col6" >0.4348</td>
#       <td id="T_cedba_row1_col7" class="data row1 col7" >0.4517</td>
#       <td id="T_cedba_row1_col8" class="data row1 col8" >2.9850</td>
#     </tr>
#     <tr>
#       <th id="T_cedba_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_cedba_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_cedba_row2_col1" class="data row2 col1" >0.7607</td>
#       <td id="T_cedba_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_cedba_row2_col3" class="data row2 col3" >0.5379</td>
#       <td id="T_cedba_row2_col4" class="data row2 col4" >0.7145</td>
#       <td id="T_cedba_row2_col5" class="data row2 col5" >0.6103</td>
#       <td id="T_cedba_row2_col6" class="data row2 col6" >0.4428</td>
#       <td id="T_cedba_row2_col7" class="data row2 col7" >0.4545</td>
#       <td id="T_cedba_row2_col8" class="data row2 col8" >0.5570</td>
#     </tr>
#     <tr>
#       <th id="T_cedba_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_cedba_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_cedba_row3_col1" class="data row3 col1" >0.7606</td>
#       <td id="T_cedba_row3_col2" class="data row3 col2" >0.8073</td>
#       <td id="T_cedba_row3_col3" class="data row3 col3" >0.5556</td>
#       <td id="T_cedba_row3_col4" class="data row3 col4" >0.7123</td>
#       <td id="T_cedba_row3_col5" class="data row3 col5" >0.6149</td>
#       <td id="T_cedba_row3_col6" class="data row3 col6" >0.4464</td>
#       <td id="T_cedba_row3_col7" class="data row3 col7" >0.4594</td>
#       <td id="T_cedba_row3_col8" class="data row3 col8" >0.6750</td>
#     </tr>
#     <tr>
#       <th id="T_cedba_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_cedba_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_cedba_row4_col1" class="data row4 col1" >0.7590</td>
#       <td id="T_cedba_row4_col2" class="data row4 col2" >0.8271</td>
#       <td id="T_cedba_row4_col3" class="data row4 col3" >0.5519</td>
#       <td id="T_cedba_row4_col4" class="data row4 col4" >0.7037</td>
#       <td id="T_cedba_row4_col5" class="data row4 col5" >0.6149</td>
#       <td id="T_cedba_row4_col6" class="data row4 col6" >0.4436</td>
#       <td id="T_cedba_row4_col7" class="data row4 col7" >0.4533</td>
#       <td id="T_cedba_row4_col8" class="data row4 col8" >0.5650</td>
#     </tr>
#     <tr>
#       <th id="T_cedba_level0_row5" class="row_heading level0 row5" >nb</th>
#       <td id="T_cedba_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_cedba_row5_col1" class="data row5 col1" >0.7542</td>
#       <td id="T_cedba_row5_col2" class="data row5 col2" >0.8171</td>
#       <td id="T_cedba_row5_col3" class="data row5 col3" >0.5983</td>
#       <td id="T_cedba_row5_col4" class="data row5 col4" >0.6765</td>
#       <td id="T_cedba_row5_col5" class="data row5 col5" >0.6323</td>
#       <td id="T_cedba_row5_col6" class="data row5 col6" >0.4486</td>
#       <td id="T_cedba_row5_col7" class="data row5 col7" >0.4528</td>
#       <td id="T_cedba_row5_col8" class
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.001, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=-1, penalty='l2',
#               power_t=0.5, random_state=2654, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)

# %%
best_model = create_model("lr")
# Out:
# <style type="text/css">
# #T_a0d48_row10_col0, #T_a0d48_row10_col1, #T_a0d48_row10_col2, #T_a0d48_row10_col3, #T_a0d48_row10_col4, #T_a0d48_row10_col5, #T_a0d48_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a0d48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0d48_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a0d48_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a0d48_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a0d48_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a0d48_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a0d48_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a0d48_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0d48_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0d48_row0_col0" class="data row0 col0" >0.6935</td>
#       <td id="T_a0d48_row0_col1" class="data row0 col1" >0.7443</td>
#       <td id="T_a0d48_row0_col2" class="data row0 col2" >0.4091</td>
#       <td id="T_a0d48_row0_col3" class="data row0 col3" >0.6000</td>
#       <td id="T_a0d48_row0_col4" class="data row0 col4" >0.4865</td>
#       <td id="T_a0d48_row0_col5" class="data row0 col5" >0.2791</td>
#       <td id="T_a0d48_row0_col6" class="data row0 col6" >0.2895</td>
#     </tr>
#     <tr>
#       <th id="T_a0d48_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a0d48_row1_col0" class="data row1 col0" >0.7258</td>
#       <td id="T_a0d48_row1_col1" class="data row1 col1" >0.8159</td>
#       <td id="T_a0d48_row1_col2" class="data row1 col2" >0.4545</td>
#       <td id="T_a0d48_row1_col3" class="data row1 col3" >0.6667</td>
#       <td id="T_a0d48_row1_col4" class="data row1 col4" >0.5405</td>
#       <td id="T_a0d48_row1_col5" class="data row1 col5" >0.3550</td>
#       <td id="T_a0d48_row1_col6" class="data row1 col6" >0.3682</td>
#     </tr>
#     <tr>
#       <th id="T_a0d48_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a0d48_row2_col0" class="data row2 col0" >0.8065</td>
#       <td id="T_a0d48_row2_col1" class="data row2 col1" >0.8545</td>
#       <td id="T_a0d48_row2_col2" class="data row2 col2" >0.6364</td>
#       <td id="T_a0d48_row2_col3" class="data row2 col3" >0.7778</td>
#       <td id="T_a0d48_row2_col4" class="data row2 col4" >0.7000</td>
#       <td id="T_a0d48_row2_col5" class="data row2 col5" >0.5592</td>
#       <td id="T_a0d48_row2_col6" class="data row2 col6" >0.5654</td>
#     </tr>
#     <tr>
#       <th id="T_a0d48_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a0d48_row3_col0" class="data row3 col0" >0.7419</td>
#       <td id="T_a0d48_row3_col1" class="data row3 col1" >0.8011</td>
#       <td id="T_a0d48_row3_col2" class="data row3 col2" >0.4091</td>
#       <td id="T_a0d48_row3_col3" class="data row3 col3" >0.7500</td>
#       <td id="T_a0d48_row3_col4" class="data row3 col4" >0.5294</td>
#       <td id="T_a0d48_row3_col5" class="data row3 col5" >0.3722</td>
#       <td id="T_a0d48_row3_col6" class="data row3 col6" >0.4046</td>
#     </tr>
#     <tr>
#       <th id="T_a0d48_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a0d48_row4_col0" class="data row4 col0" >0.7541</td>
#       <td id="T_a0d48_row4_col1" class="data row4 col1" >0.8643</td>
#       <td id="T_a0d48_row4_col2" class="data row4 col2" >0.3810</td>
#       <td id="T_a0d48_row4_col3" class="data row4 col3" >0.8000</td>
#       <td id="T_a0d48_row4_col4" class="data row4 col4" >0.5161</td>
#       <td id="T_a0d48_row4_col5" class="data row4 col5" >0.3780</td>
#       <td id="T_a0d48_row4_col6" class="data row4 col6" >0.4247</td>
#     </tr>
#     <tr>
#       <th id="T_a0d48_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a0d48_row5_col0" class="data row5 col0" >0.8525</td>
#       <td id="T_a0d48_row5_col1" class="data row5 col1" >0.9286</td>
#       <td id="T_a0d48_row5_col2" class="data row5 col2" >0.6190</td>
#       <td id="T_a0d48_row5_col3" class="data row5 col3" >0.9286</td>
#       <td id="T_a0d48_row5_col4" class="data row5 col4" >0.7429</td>
#       <td id="T_a0d48_row5_col5" class="data row5 col5" >0.6451</td>
#       <td id="T_a0d48_row5_col6" class="data row5 col6" >0.6712</td>
#     </tr>
#     <tr>
#       <th id="T_a0d48_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a0d48_row6_col0" class="data row6 col0" >0.6885</td>
#       <td id="T_a0d48_row6_col1" class="data row6 col1" >0.6464</td>
#       <td id="T_a0d48_row6_col2" class="data row6 col2" >0.3810</td>
#       <td id="T_a0d48_row6_col3" class="data row6 col3" >0.5714</td>
#       <td id="T_a0d48_row6_col4" class="data row6 col4" >0.4571</td>
#       <td id="T_a0d48_row6_col5" class="data row6 col5" >0.2508</td>
#       <td id="T_a0d48_row6_col6" class="data row6 col6" >0.2609</td>
#     </tr>
#     <tr>
#       <th id="T_a0d48_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a0d48_row7_col0" class="data row7 col0" >0.8033</td>
#       <td id="T_a0d48_row7_col1" class="data row7 col1" >0.8369</td>
#       <td id="T_a0d48_row7_col2" class="data row7 col2" >0.6667</td>
#       <td id="T_a0d48_row7_col3" class="data row7 col3" >0.7368</td>
#       <td id="T_a0d48_row7_col4" class="data row7 col4" >0.7000</td>
#       <td id="T_a0d48_row7_col5" class="data row7 col5" >0.5542</td>
#       <td id="T_a0d48_row7_col6" class="data row7 col6" >0.5557</td>
#     </tr>
#     <tr>
#       <th id="T_a0d48_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a0d48_row8_col0" class="data row8 col0" >0.7869</td>
#       <td id="T_a0d48_row8_col1" class="data row8 col1" >0.8976</td>
#       <td id="T_a0d48_row8_col2" class="data row8 col2" >0.5714</td>
#       <td id="T_a0d48_row8_col3" class="data row8 col3" >0.7500</td>
#       <td id="T_a0d48_row8_col4" class="data row8 col4" >0.6486</td>
#       <td id="T_a0d48_row8_col5" class="data row8 col5" >0.4997</td>
#       <td id="T_a0d48_row8_col6" class="data row8 col6" >0.5092</td>
#     </tr>
#     <tr>
#       <th id="T_a0d48_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a0d48_row9_col0" class="data row9 col0" >0.7705</td>
#       <td id="T_a0d48_row9_col1" class="data row9 col1" >0.8690</td>
#       <td id="T_a0d48_row9_col2" class="data row9 col2" >0.5238</td>
#       <td id="T_a0d48_row9_col3" class="data row9 col3" >0.7333</td>
#       <td id="T_a0d48_row9_col4" class="data row9 col4" >0.6111</td>
#       <td id="T_a0d48_row9_col5" class="data row9 col5" >0.4547</td>
#       <td id="T_a0d48_row9_col6" class="data row9 col6" >0.4676</td>
#     </tr>
#     <tr>
#       <th id="T_a0d48_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a0d48_row10_col0" class="data row10 col0" >0.7623</td>
#       <td id="T_a0d48_row10_col1" class="data row10 col1" >0.8259</td>
#       <td id="T_a0d48_row10_col2" class="data row10 col2" >0.5052</td>
#       <td id="T_a0d48_row10_col3" class="data row10 col3" >0.7315</td>
#       <td id="T_a0d48_row10_col4" class="data row10 col4" >0.5932</td>
#       <td id="T_a0d48_row10_col5" class="data row10 col5" >0.4348</td>
#       <td id="T_a0d48_row10_col6" class="data row10 col6" >0.4517</td>
#     </tr>
#     <tr>
#       <th id="T_a0d48_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_a0d48_row11_col0" class="data row11 col0" >0.0494</td>
#       <td id="T_a0d48_row11_col1" class="data row11 col1" >0.0772</td>
#       <td id="T_a0d48_row11_col2" class="data row11 col2" >0.1062</td>
#       <td id="T_a0d48_row11_col3" class="data row11 col3" >0.0967</td>
#       <td id="T_a0d48_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
print(best_model)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=2654, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# # On tune le modele

# %%
tuned_best_model = tune_model(best_model,choose_better = True)
# Out:
# <style type="text/css">
# #T_953cf_row10_col0, #T_953cf_row10_col1, #T_953cf_row10_col2, #T_953cf_row10_col3, #T_953cf_row10_col4, #T_953cf_row10_col5, #T_953cf_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_953cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_953cf_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_953cf_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_953cf_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_953cf_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_953cf_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_953cf_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_953cf_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_953cf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_953cf_row0_col0" class="data row0 col0" >0.6613</td>
#       <td id="T_953cf_row0_col1" class="data row0 col1" >0.7511</td>
#       <td id="T_953cf_row0_col2" class="data row0 col2" >0.4091</td>
#       <td id="T_953cf_row0_col3" class="data row0 col3" >0.5294</td>
#       <td id="T_953cf_row0_col4" class="data row0 col4" >0.4615</td>
#       <td id="T_953cf_row0_col5" class="data row0 col5" >0.2204</td>
#       <td id="T_953cf_row0_col6" class="data row0 col6" >0.2243</td>
#     </tr>
#     <tr>
#       <th id="T_953cf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_953cf_row1_col0" class="data row1 col0" >0.7581</td>
#       <td id="T_953cf_row1_col1" class="data row1 col1" >0.8159</td>
#       <td id="T_953cf_row1_col2" class="data row1 col2" >0.5455</td>
#       <td id="T_953cf_row1_col3" class="data row1 col3" >0.7059</td>
#       <td id="T_953cf_row1_col4" class="data row1 col4" >0.6154</td>
#       <td id="T_953cf_row1_col5" class="data row1 col5" >0.4431</td>
#       <td id="T_953cf_row1_col6" class="data row1 col6" >0.4510</td>
#     </tr>
#     <tr>
#       <th id="T_953cf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_953cf_row2_col0" class="data row2 col0" >0.8226</td>
#       <td id="T_953cf_row2_col1" class="data row2 col1" >0.8614</td>
#       <td id="T_953cf_row2_col2" class="data row2 col2" >0.6818</td>
#       <td id="T_953cf_row2_col3" class="data row2 col3" >0.7895</td>
#       <td id="T_953cf_row2_col4" class="data row2 col4" >0.7317</td>
#       <td id="T_953cf_row2_col5" class="data row2 col5" >0.6002</td>
#       <td id="T_953cf_row2_col6" class="data row2 col6" >0.6038</td>
#     </tr>
#     <tr>
#       <th id="T_953cf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_953cf_row3_col0" class="data row3 col0" >0.7419</td>
#       <td id="T_953cf_row3_col1" class="data row3 col1" >0.7886</td>
#       <td id="T_953cf_row3_col2" class="data row3 col2" >0.4091</td>
#       <td id="T_953cf_row3_col3" class="data row3 col3" >0.7500</td>
#       <td id="T_953cf_row3_col4" class="data row3 col4" >0.5294</td>
#       <td id="T_953cf_row3_col5" class="data row3 col5" >0.3722</td>
#       <td id="T_953cf_row3_col6" class="data row3 col6" >0.4046</td>
#     </tr>
#     <tr>
#       <th id="T_953cf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_953cf_row4_col0" class="data row4 col0" >0.7705</td>
#       <td id="T_953cf_row4_col1" class="data row4 col1" >0.8750</td>
#       <td id="T_953cf_row4_col2" class="data row4 col2" >0.4762</td>
#       <td id="T_953cf_row4_col3" class="data row4 col3" >0.7692</td>
#       <td id="T_953cf_row4_col4" class="data row4 col4" >0.5882</td>
#       <td id="T_953cf_row4_col5" class="data row4 col5" >0.4411</td>
#       <td id="T_953cf_row4_col6" class="data row4 col6" >0.4655</td>
#     </tr>
#     <tr>
#       <th id="T_953cf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_953cf_row5_col0" class="data row5 col0" >0.8525</td>
#       <td id="T_953cf_row5_col1" class="data row5 col1" >0.9286</td>
#       <td id="T_953cf_row5_col2" class="data row5 col2" >0.6190</td>
#       <td id="T_953cf_row5_col3" class="data row5 col3" >0.9286</td>
#       <td id="T_953cf_row5_col4" class="data row5 col4" >0.7429</td>
#       <td id="T_953cf_row5_col5" class="data row5 col5" >0.6451</td>
#       <td id="T_953cf_row5_col6" class="data row5 col6" >0.6712</td>
#     </tr>
#     <tr>
#       <th id="T_953cf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_953cf_row6_col0" class="data row6 col0" >0.6393</td>
#       <td id="T_953cf_row6_col1" class="data row6 col1" >0.6512</td>
#       <td id="T_953cf_row6_col2" class="data row6 col2" >0.4286</td>
#       <td id="T_953cf_row6_col3" class="data row6 col3" >0.4737</td>
#       <td id="T_953cf_row6_col4" class="data row6 col4" >0.4500</td>
#       <td id="T_953cf_row6_col5" class="data row6 col5" >0.1827</td>
#       <td id="T_953cf_row6_col6" class="data row6 col6" >0.1832</td>
#     </tr>
#     <tr>
#       <th id="T_953cf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_953cf_row7_col0" class="data row7 col0" >0.8033</td>
#       <td id="T_953cf_row7_col1" class="data row7 col1" >0.8548</td>
#       <td id="T_953cf_row7_col2" class="data row7 col2" >0.7143</td>
#       <td id="T_953cf_row7_col3" class="data row7 col3" >0.7143</td>
#       <td id="T_953cf_row7_col4" class="data row7 col4" >0.7143</td>
#       <td id="T_953cf_row7_col5" class="data row7 col5" >0.5643</td>
#       <td id="T_953cf_row7_col6" class="data row7 col6" >0.5643</td>
#     </tr>
#     <tr>
#       <th id="T_953cf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_953cf_row8_col0" class="data row8 col0" >0.8033</td>
#       <td id="T_953cf_row8_col1" class="data row8 col1" >0.8940</td>
#       <td id="T_953cf_row8_col2" class="data row8 col2" >0.6190</td>
#       <td id="T_953cf_row8_col3" class="data row8 col3" >0.7647</td>
#       <td id="T_953cf_row8_col4" class="data row8 col4" >0.6842</td>
#       <td id="T_953cf_row8_col5" class="data row8 col5" >0.5436</td>
#       <td id="T_953cf_row8_col6" class="data row8 col6" >0.5500</td>
#     </tr>
#     <tr>
#       <th id="T_953cf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_953cf_row9_col0" class="data row9 col0" >0.7705</td>
#       <td id="T_953cf_row9_col1" class="data row9 col1" >0.8583</td>
#       <td id="T_953cf_row9_col2" class="data row9 col2" >0.5238</td>
#       <td id="T_953cf_row9_col3" class="data row9 col3" >0.7333</td>
#       <td id="T_953cf_row9_col4" class="data row9 col4" >0.6111</td>
#       <td id="T_953cf_row9_col5" class="data row9 col5" >0.4547</td>
#       <td id="T_953cf_row9_col6" class="data row9 col6" >0.4676</td>
#     </tr>
#     <tr>
#       <th id="T_953cf_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_953cf_row10_col0" class="data row10 col0" >0.7623</td>
#       <td id="T_953cf_row10_col1" class="data row10 col1" >0.8279</td>
#       <td id="T_953cf_row10_col2" class="data row10 col2" >0.5426</td>
#       <td id="T_953cf_row10_col3" class="data row10 col3" >0.7159</td>
#       <td id="T_953cf_row10_col4" class="data row10 col4" >0.6129</td>
#       <td id="T_953cf_row10_col5" class="data row10 col5" >0.4467</td>
#       <td id="T_953cf_row10_col6" class="data row10 col6" >0.4585</td>
#     </tr>
#     <tr>
#       <th id="T_953cf_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_953cf_row11_col0" class="data row11 col0" >0.0640</td>
#       <td id="T_953cf_row11_col1" class="data row11 col1" >0.0764</td>
#       <td id="T_953cf_row11_col2" class="data row11 col2" >0.1068</td>
#       <td id="T_953cf_row11_col3" class="data row11 col3" >0.1228</td>
#       <td id="T_953cf_row11_col4
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
#On constate une diminution de l accuracy après l optimisation

# %% [markdown]
# # Visualisation

# %% [markdown]
# ### Visualisation d e l'importance des variables

# %%
plot_model(best_model, plot='manifold')

# %%
# interpret_model(best_model)

# %%
plot_model(best_model, plot='feature')

# %% [markdown]
# ### Confusion Matrix

# %%
plot_model(best_model, plot = 'confusion_matrix')

# %% [markdown]
# ### AUROC Plot

# %%
#Visualiser le modèle
plot_model(best_model,plot="auc")

# %% [markdown]
# ###  Precision Recall Plot

# %%
plot_model(best_model, plot = 'pr')

# %% [markdown]
# # Prediction sur le dataset

# %%
predict_model(best_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c06d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c06d8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c06d8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_c06d8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_c06d8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_c06d8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_c06d8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_c06d8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_c06d8_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c06d8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c06d8_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_c06d8_row0_col1" class="data row0 col1" >0.7727</td>
#       <td id="T_c06d8_row0_col2" class="data row0 col2" >0.8696</td>
#       <td id="T_c06d8_row0_col3" class="data row0 col3" >0.4815</td>
#       <td id="T_c06d8_row0_col4" class="data row0 col4" >0.7879</td>
#       <td id="T_c06d8_row0_col5" class="data row0 col5" >0.5977</td>
#       <td id="T_c06d8_row0_col6" class="data row0 col6" >0.4519</td>
#       <td id="T_c06d8_row0_col7" class="data row0 col7" >0.4785</td>
#     </tr>
#   </tbody>
# </table>
#      Pregnancies  Glucose  BloodPressure        BMI  DiabetesPedigreeFunction  \
# 731            8      120             86  28.400000                     0.259
# 315            2      112             68  34.099998                     0.315
# 52             5       88             66  24.400000                     0.342
# 760            2       88             58  28.400000                     0.766
# 31             3      158             76  31.600000                     0.851
# ..           ...      ...            ...        ...                       ...
# 2              8      183             64  23.299999                     0.672
# 130            4      173             70  29.700001                     0.361
# 343            5      122             86  34.700001                     0.290
# 297            0      126             84  30.700001                     0.520
# 571            2      130             96  22.600000                     0.268
#
#      Age  Outcome  prediction_label  prediction_score
# 731   22        1                 0            0.7386
# 315   26        0                 0            0.7769
# 52    30        0                 0            0.8596
# 760   22        0                 0            0.8470
# 31    28        1                 0            0.5002
# ..   ...      ...               ...               ...
# 2     32        1                 1            0.6467
# 130   33        1                 1            0.5282
# 343   33        0                 0            0.6794
# 297   24        0                 0            0.7872
# 571   21        0                 0            0.8488
#
# [154 rows x 9 columns]

# %% [markdown]
# # Savegarde le model

# %%
final_gbc = finalize_model(best_model)

# %%
save_model(best_model,'Final_diabetes_model_4Avril2022')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\nanji\AppData\Local\Temp\joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Pregnancies', 'Glucose',
#                                               'BloodPressure', 'BMI',
#                                               'DiabetesPedigreeFunction',
#                                               'Age'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                missing_values=nan,
#                                                                strategy='mean',
#                                                                verbose=0))),
#                  ('c...
#                   TransformerWrapper(exclude=None, include=None,
#                                      transformer=MinMaxScaler(clip=False,
#                                                               copy=True,
#                                                               feature_range=(0,
#                                                                              1)))),
#                  ('trained_model',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=2654,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  'Final_diabetes_model_4Avril2022.pkl')

# %%
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
